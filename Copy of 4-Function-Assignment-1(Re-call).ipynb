# %%
from All_Functions_Function_Assignment_1 import AllFunctionsOfAssignment

# %%
AllFunctionsOfAssignment.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
AllFunctionsOfAssignment.OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number
# '52452 is Even number'

# %%
AllFunctionsOfAssignment.Elegible()
# Out:
# Enter Your Gender: Male
# Enter Your Age: 20
# Not Eligible
# 'Not Eligible'

# %%
AllFunctionsOfAssignment.percentage()
# Out:
#         Subject1= 98
#         Subject2= 87
#         Subject3= 95
#         Subject4= 95
#         Subject5= 93
#
# Total:  468
# Percentage: 93.6000000000
# (468, 93.6)

# %%
AllFunctionsOfAssignment.triangle()
# Out:
# Enter the Height: 34
# Enter the Breadth: 32
# Enter the Height1: 4
# Enter the Height2: 2
# Area of the Triangle:  544.0
# Perimeter of the Triangle:  38.0
# (544.0, 38.0)
